# %% [markdown]
# # Board Game Recommender

# %% [markdown]
# ### Import libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

# %%
games_df_full = pd.read_csv('./data/clean/games_df.csv', index_col=0)
# Out:
# c:\programdata\miniconda3\envs\newenv\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
games_df_full.head(1)
# Out:
#           user  rating comment     ID       name  \
# 360434  166554     6.0     NaN  68448  7 Wonders
#
#                                               description  minplayers  \
# 360434  You are the leader of one of the 7 great citie...           2
#
#         maxplayers  playingtime  minage  usersrated  average
# 360434           7           30      10       79873  7.76049

# %%
# subset of full dataset for recommender
games_df = games_df_full[['name', 'ID', 'user', 'rating']]

# %%
#create a sample dataframe with less entries, sample 100,000 reviews
games_df_subset = games_df.sample(n=100000, replace=False)
games_df_subset.shape
# Out:
# (100000, 4)

# %% [markdown]
# ### Prepare recommender using cosine distances

# %%
#pivot table from the books_df dataframe
pivot_df = pd.pivot_table(games_df_subset, index='name', columns='user', values='rating')
#create sparse matrix
sparse_df = sparse.csr_matrix(pivot_df.fillna(0))
#calculate cosine distances for similarities
recommender = pairwise_distances(sparse_df, metric='cosine')
#export as a dataframe
rec_df = pd.DataFrame(recommender, columns=pivot_df.index, index=pivot_df.index)

# %%
# get average rating, number of players, playing time, etc to filter by in app, group by game ID
games_info = games_df_full.groupby('name').mean()
games_info.drop(columns=['user'], inplace=True)
games_info.rename(columns={'rating': 'average_rating'}, inplace=True)
games_info.head(2)

rec_df = pd.merge(left = rec_df, right= games_info, right_index = True, left_index = True)

# %% [markdown]
# ### Define book Recommender function

# %%
rec_df
# Out:
#                                                     "Oh My God! There's An Axe In My Head." The Game of International Diplomacy   \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                                                0.0
# '65: Squad-Level Combat in the Jungles of Vietnam                                                 1.0
# ...and then, we held hands.                                                                       1.0
# ...und tschüss!                                                                                   1.0
# 011                                                                                               1.0
# ...                                                                                               ...
# Свинтус                                                                                           1.0
# Экивоки                                                                                           1.0
# €uro Crisis                                                                                       1.0
# なつめも (Natsumemo)                                                                                  1.0
# ひとひら (Hitohira)                                                                                   1.0
#
#                                                     '65: Squad-Level Combat in the Jungles of Vietnam  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                                                1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                                                 0.0
# ...and then, we held hands.                                                                       1.0
# ...und tschüss!                                                                                   1.0
# 011                                                                                               1.0
# ...                                                                                               ...
# Свинтус                                                                                           1.0
# Экивоки                                                                                           1.0
# €uro Crisis                                                                                       1.0
# なつめも (Natsumemo)                                                                                  1.0
# ひとひら (Hitohira)                                                                                   1.0
#
#                                                     ...and then, we held hands.  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                          1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                           1.0
# ...and then, we held hands.                                                 0.0
# ...und tschüss!                                                             1.0
# 011                                                                         1.0
# ...                                                                         ...
# Свинтус                                                                     1.0
# Экивоки                                                                     1.0
# €uro Crisis                                                                 1.0
# なつめも (Natsumemo)                                                            1.0
# ひとひら (Hitohira)                                                             1.0
#
#                                                     ...und tschüss!  011  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...              1.0  1.0
# '65: Squad-Level Combat in the Jungles of Vietnam               1.0  1.0
# ...and then, we held hands.                                     1.0  1.0
# ...und tschüss!                                                 0.0  1.0
# 011                                                             1.0  0.0
# ...                                                             ...  ...
# Свинтус                                                         1.0  1.0
# Экивоки                                                         1.0  1.0
# €uro Crisis                                                     1.0  1.0
# なつめも (Natsumemo)                                                1.0  1.0
# ひとひら (Hitohira)                                                 1.0  1.0
#
#                                                     1 Stein + Co.  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...            1.0
# '65: Squad-Level Combat in the Jungles of Vietnam             1.0
# ...and then, we held hands.                                   1.0
# ...und tschüss!                                               1.0
# 011                                                           1.0
# ...                                                           ...
# Свинтус                                                       1.0
# Экивоки                                                       1.0
# €uro Crisis                                                   1.0
# なつめも (Natsumemo)                                              1.0
# ひとひら (Hitohira)                                               1.0
#
#                                                     1,000 Places to See Before You Die  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                                 1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                                  1.0
# ...and then, we held hands.                                                        1.0
# ...und tschüss!                                                                    1.0
# 011                                                                                1.0
# ...                                                                                ...
# Свинтус                                                                            1.0
# Экивоки                                                                            1.0
# €uro Crisis                                                                        1.0
# なつめも (Natsumemo)                                                                   1.0
# ひとひら (Hitohira)                                                                    1.0
#
#                                                     1,2,3! Now you see me...  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                       1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                        1.0
# ...and then, we held hands.                                              1.0
# ...und tschüss!                                                          1.0
# 011                                                                      1.0
# ...                                                                      ...
# Свинтус                                                                  1.0
# Экивоки                                                                  1.0
# €uro Crisis                                                              1.0
# なつめも (Natsumemo)                                                         1.0
# ひとひら (Hitohira)                                                          1.0
#
#                                                     10 Days in Africa  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...                1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                 1.0
# ...and then, we held hands.                                       1.0
# ...und tschüss!                                                   1.0
# 011                                                               1.0
# ...                                                               ...
# Свинтус                                                           1.0
# Экивоки                                                           1.0
# €uro Crisis                                                       1.0
# なつめも (Natsumemo)                                                  1.0
# ひとひら (Hitohira)                                                   1.0
#
#                                                     10 Days in Asia  ...  \
# name                                                                 ...
# "Oh My God! There's An Axe In My Head." The Gam...              1.0  ...
# '65: Squad-Level Combat in the Jungles of Vietnam               1.0  ...
# ...and then, we held hands.                                     1.0  ...
# ...und tschüss!                                                 1.0  ...
# 011                                                             1.0  ...
# ...                                                             ...  ...
# Свинтус                                                         1.0  ...
# Экивоки                                                         1.0  ...
# €uro Crisis                                                     1.0  ...
# なつめも (Natsumemo)                                                1.0  ...
# ひとひら (Hitohira)                                                 1.0  ...
#
#                                                     なつめも (Natsumemo)  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...               1.0
# '65: Squad-Level Combat in the Jungles of Vietnam                1.0
# ...and then, we held hands.                                      1.0
# ...und tschüss!                                                  1.0
# 011                                                              1.0
# ...                                                              ...
# Свинтус                                                          1.0
# Экивоки                                                          1.0
# €uro Crisis                                                      1.0
# なつめも (Natsumemo)                                                 0.0
# ひとひら (Hitohira)                                                  1.0
#
#                                                     ひとひら (Hitohira)  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...              1.0
# '65: Squad-Level Combat in the Jungles of Vietnam               1.0
# ...and then, we held hands.                                     1.0
# ...und tschüss!                                                 1.0
# 011                                                             1.0
# ...                                                             ...
# Свинтус                                                         1.0
# Экивоки                                                         1.0
# €uro Crisis                                                     1.0
# なつめも (Natsumemo)                                                1.0
# ひとひら (Hitohira)                                                 0.0
#
#                                                     average_rating        ID  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...        5.696000   23304.0
# '65: Squad-Level Combat in the Jungles of Vietnam         7.802041  188325.0
# ...and then, we held hands.                               6.053841  153999.0
# ...und tschüss!                                           6.520745     853.0
# 011                                                       6.126838   93194.0
# ...                                                            ...       ...
# Свинтус                                                   5.380800   46147.0
# Экивоки                                                   6.715789  297864.0
# €uro Crisis                                               7.061290  165022.0
# なつめも (Natsumemo)                                          7.586170  280811.0
# ひとひら (Hitohira)                                           6.850000  176642.0
#
#                                                     minplayers  maxplayers  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...         2.0         6.0
# '65: Squad-Level Combat in the Jungles of Vietnam          2.0         3.0
# ...and then, we held hands.                                2.0         2.0
# ...und tschüss!                                            4.0         6.0
# 011                                                        3.0         6.0
# ...                                                        ...         ...
# Свинтус                                                    2.0         8.0
# Экивоки                                                    2.0        16.0
# €uro Crisis                                                3.0         4.0
# なつめも (Natsumemo)                                           3.0         6.0
# ひとひら (Hitohira)                                            2.0         4.0
#
#                                                     playingtime  minage  \
# name
# "Oh My God! There's An Axe In My Head." The Gam...         60.0    16.0
# '65: Squad-Level Combat in the Jungles of Vietnam         180.0    12.0
# ...and then, we held hands.                                45.0    12.0
# ...und tschüss!                                            30.0    10.0
# 011                                                        90.0    12.0
# ...                                                         ...     ...
# Свинтус                                                    30.0     6.0
# Экивоки                                                    60.0    16.0
# €uro Crisis                                                90.0    14.0
# なつめも (Natsumemo)                                           45.0     8.0
# ひとひら (Hitohira)                                            30.0     8.0
#
#                                                     usersrated  average
# name
# "Oh My God! There's An Axe In My Head." The Gam...        79.0  5.90557
# '65: Squad-Level Combat in the Jungles of Vietnam        134.0  7.70112
# ...and then, we held hands.                             1767.0  6.11144
# ...und tschüss!                                          322.0  6.41807
# 011                                                      414.0  6.10952
# ...                                                        ...      ...
# Свинтус                                                  164.0  5.45268
# Экивоки                                                   37.0  6.73243
# €uro Crisis                                               95.0  7.01905
# なつめも (Natsumemo)                                         125.0  7.42520
# ひとひら (Hitohira)                                           39.0  6.48641
#
# [11086 rows x 11094 columns]

# %%
games_df_full[games_df_full['name'] =='Dominion: Intrigue'][:1]
# Out:
#            user  rating comment     ID                name  \
# 2444546  179379     6.5     NaN  40834  Dominion: Intrigue
#
#                                                description  minplayers  \
# 2444546  In Dominion: Intrigue (as with Dominion), each...           2
#
#          maxplayers  playingtime  minage  usersrated  average
# 2444546           4           30      13       29221   7.7271

# %%
games_df_full[games_df_full['name'] =='Roll for the Galaxy'][:1]
# Out:
#            user  rating comment      ID                 name  \
# 3154527  159712     8.0     NaN  132531  Roll for the Galaxy
#
#                                                description  minplayers  \
# 3154527  Game description from the publisher:&#10;&#10;...           2
#
#          maxplayers  playingtime  minage  usersrated  average
# 3154527           5           45      13       24804   7.6873

# %%
def game_recommender(game_title, average_rating = 7.5, minplayers = -np.inf, playingtime = np.inf):
    rec_df2 = rec_df[rec_df['average_rating'] >= average_rating]
    rec_df3 = rec_df2[rec_df2['minplayers'] >= minplayers]
    rec_df4 = rec_df3[rec_df3['playingtime'] <= playingtime]
    return 1- rec_df4[game_title].sort_values()[1:6]

# %%
game_recommender('Cosmic Encounter')
# Out:
# name
# Star Trek: Attack Wing           0.032615
# The Lord of the Ice Garden       0.032298
# Black Sonata                     0.025629
# Cataclysm: A Second World War    0.023602
# Wilderness War                   0.022686
# Name: Cosmic Encounter, dtype: float64

# %%
#add game title, re-arrange for streamlit app
rec_df.insert(0, "game_title", rec_df.index)

# save rec_df for use in streamlit app
rec_df.to_pickle('./streamlit_app/data/games.pk1')

# %%
rec_df['playingtime'].max()
# Out:
# 22500.0
